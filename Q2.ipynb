# %% [markdown]
# <a href="https://colab.research.google.com/github/jjon215/MLHW1/blob/master/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import keras
import numpy as np
from keras.datasets import mnist

batch_size = 100
expments = 50
learn_rate = 0.005

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = (x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2]))
y_train = (keras.utils.to_categorical(y_train,10))
x_test = (x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2]))
y_tes = y_test
y_test = (keras.utils.to_categorical(y_test,10))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
def initialize_parameters():
  W = np.random.randn(10,784)*0.01
  b = np.random.randn(10,1)
  return W,b
def forward_propagation(W,b,x):
  output = np.dot(W,np.transpose(x)) + (b)
  output = sigmoid(output)
  return output
def sigmoid(x): 
  z = 1/(1+np.exp(-x))
  return z
def loss_function(y_train,output):
  loss = np.sum(np.multiply(np.transpose(y_train),np.log(output))+np.multiply(np.transpose(y_train),np.log(output)),axis=1,keepdims=True)/batch_size
  return loss
def backward_propagation(x_train,y_train,output,W,b,learn_rate,batch_size):
  
  der_loss = output - np.transpose(y_train)
  der_z = der_loss
  der_W = np.dot(der_z,x_train)
  der_b = np.sum(der_z,axis=1,keepdims=True)
  W = W - learn_rate*der_W
  b = b - learn_rate*der_b
  return W,b

# %%
W,b = initialize_parameters()
for j in range(expments):
  for i in range(0, x_train.shape[0], batch_size):
    output = forward_propagation(W,b,x_train[i:i+batch_size])
    W,b = backward_propagation(x_train[i:i+batch_size],y_train[i:i+batch_size],output,W,b,learn_rate,batch_size)
  out = forward_propagation(W,b,x_test)
  out = np.transpose(out)
  out_list = list()
  for i in range(10000):
    out_list.append(np.argmax(out[i]))
  count = 0
  for i in range(10000):
    if out_list[i] == y_tes[i]:
      count += 1
  out_list = []
  acc = count/100
  print("Epoch Iteration:",j)
  print(count,"/10000")
  print("Accuracy is :",acc)
# Out:
# Epoch Iteration: 0
# 9037 /10000
# Accuracy is : 90.37
# Epoch Iteration: 1
# 9073 /10000
# Accuracy is : 90.73
# Epoch Iteration: 2
# 9096 /10000
# Accuracy is : 90.96
# Epoch Iteration: 3
# 9100 /10000
# Accuracy is : 91.0
# Epoch Iteration: 4
# 9105 /10000
# Accuracy is : 91.05
# Epoch Iteration: 5
# 9105 /10000
# Accuracy is : 91.05
# Epoch Iteration: 6
# 9104 /10000
# Accuracy is : 91.04
# Epoch Iteration: 7
# 9108 /10000
# Accuracy is : 91.08
# Epoch Iteration: 8
# 9111 /10000
# Accuracy is : 91.11
# Epoch Iteration: 9
# 9112 /10000
# Accuracy is : 91.12
# Epoch Iteration: 10
# 9115 /10000
# Accuracy is : 91.15
# Epoch Iteration: 11
# 9120 /10000
# Accuracy is : 91.2
# Epoch Iteration: 12
# 9123 /10000
# Accuracy is : 91.23
# Epoch Iteration: 13
# 9126 /10000
# Accuracy is : 91.26
# Epoch Iteration: 14
# 9126 /10000
# Accuracy is : 91.26
# Epoch Iteration: 15
# 9124 /10000
# Accuracy is : 91.24
# Epoch Iteration: 16
# 9128 /10000
# Accuracy is : 91.28
# Epoch Iteration: 17
# 9131 /10000
# Accuracy is : 91.31
# Epoch Iteration: 18
# 9132 /10000
# Accuracy is : 91.32
# Epoch Iteration: 19
# 9132 /10000
# Accuracy is : 91.32
# Epoch Iteration: 20
# 9134 /10000
# Accuracy is : 91.34
# Epoch Iteration: 21
# 9136 /10000
# Accuracy is : 91.36
# Epoch Iteration: 22
# 9136 /10000
# Accuracy is : 91.36
# Epoch Iteration: 23
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 24
# 9137 /10000
# Accuracy is : 91.37
# Epoch Iteration: 25
# 9134 /10000
# Accuracy is : 91.34
# Epoch Iteration: 26
# 9135 /10000
# Accuracy is : 91.35
# Epoch Iteration: 27
# 9136 /10000
# Accuracy is : 91.36
# Epoch Iteration: 28
# 9137 /10000
# Accuracy is : 91.37
# Epoch Iteration: 29
# 9137 /10000
# Accuracy is : 91.37
# Epoch Iteration: 30
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 31
# 9139 /10000
# Accuracy is : 91.39
# Epoch Iteration: 32
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 33
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 34
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 35
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 36
# 9137 /10000
# Accuracy is : 91.37
# Epoch Iteration: 37
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 38
# 9138 /10000
# Accuracy is : 91.38
# Epoch Iteration: 39
# 9138 /10000
# Accuracy is : 91.38
