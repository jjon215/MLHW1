# %% [markdown]
# <a href="https://colab.research.google.com/github/jjon215/MLHW1/blob/master/Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import keras
import numpy as np
from keras.datasets import mnist

batch_size = 100
expments = 40
learn_rate = 0.005

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = (x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2]))
y_train = (keras.utils.to_categorical(y_train,10))

x_test = (x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2]))
y_tes = y_test
y_test = (keras.utils.to_categorical(y_test,10))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(y_te.shape)
def initialize_parameters():
  W = (np.random.randn(10,784))*0.01
  b = (np.random.randn(10,1))*0.01
  return W,b
def softmax(input):
  sumer = np.sum(np.exp(input), axis = 0, keepdims = True)
  output = np.exp(input)/sumer  
  return output
def forward_propagation(W,b,x):
  part1 = np.dot(W,np.transpose(x)) + b
  part2 = softmax(part1)
  return part2
def backward_propagation(x,y,output,W,b,learn_rate,batch_size):
  der_z = output - np.transpose(y)
  der_W = np.dot(der_z,x)
  der_b = np.sum(der_z, axis = 1, keepdims = True)
  W = W - learn_rate*der_W
  b = b - learn_rate*der_b
  return W, b
W,b = initialize_parameters()
for j in range(expments):
  for i in range(0, len(x_train), batch_size):
    output = forward_propagation(W,b,x_train[i:i+batch_size])
    W,b = backward_propagation(x_train[i:i+batch_size],y_train[i:i+batch_size],output,W,b,learn_rate,batch_size)

  out = forward_propagation(W,b,x_test)
  out = np.transpose(out)
  out_list = list()
  for i in range(10000):
    out_list.append(np.argmax(out[i]))
  count = 0
  for i in range(10000):
    if out_list[i] == y_tes[i]:
      count += 1
  out_list = []
  acc = count/100
  print("Epoch Iteration:",j)
  print(count,"/10000")
  print("Accuracy is :",acc)
# Out:
# (60000, 784)
# (60000, 10)
# (10000, 784)
# (10000, 10)
# (10000,)
# Epoch Iteration: 0
# 9051 /10000
# Accuracy is : 90.51
# Epoch Iteration: 1
# 9100 /10000
# Accuracy is : 91.0
# Epoch Iteration: 2
# 9111 /10000
# Accuracy is : 91.11
# Epoch Iteration: 3
# 9129 /10000
# Accuracy is : 91.29
# Epoch Iteration: 4
# 9144 /10000
# Accuracy is : 91.44
# Epoch Iteration: 5
# 9150 /10000
# Accuracy is : 91.5
# Epoch Iteration: 6
# 9152 /10000
# Accuracy is : 91.52
# Epoch Iteration: 7
# 9152 /10000
# Accuracy is : 91.52
# Epoch Iteration: 8
# 9152 /10000
# Accuracy is : 91.52
# Epoch Iteration: 9
# 9154 /10000
# Accuracy is : 91.54
# Epoch Iteration: 10
# 9157 /10000
# Accuracy is : 91.57
# Epoch Iteration: 11
# 9157 /10000
# Accuracy is : 91.57
# Epoch Iteration: 12
# 9160 /10000
# Accuracy is : 91.6
# Epoch Iteration: 13
# 9164 /10000
# Accuracy is : 91.64
# Epoch Iteration: 14
# 9165 /10000
# Accuracy is : 91.65
# Epoch Iteration: 15
# 9170 /10000
# Accuracy is : 91.7
# Epoch Iteration: 16
# 9172 /10000
# Accuracy is : 91.72
# Epoch Iteration: 17
# 9172 /10000
# Accuracy is : 91.72
# Epoch Iteration: 18
# 9170 /10000
# Accuracy is : 91.7
# Epoch Iteration: 19
# 9169 /10000
# Accuracy is : 91.69
# Epoch Iteration: 20
# 9168 /10000
# Accuracy is : 91.68
# Epoch Iteration: 21
# 9166 /10000
# Accuracy is : 91.66
# Epoch Iteration: 22
# 9170 /10000
# Accuracy is : 91.7
# Epoch Iteration: 23
# 9173 /10000
# Accuracy is : 91.73
# Epoch Iteration: 24
# 9172 /10000
# Accuracy is : 91.72
# Epoch Iteration: 25
# 9170 /10000
# Accuracy is : 91.7
# Epoch Iteration: 26
# 9173 /10000
# Accuracy is : 91.73
# Epoch Iteration: 27
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 28
# 9174 /10000
# Accuracy is : 91.74
# Epoch Iteration: 29
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 30
# 9172 /10000
# Accuracy is : 91.72
# Epoch Iteration: 31
# 9173 /10000
# Accuracy is : 91.73
# Epoch Iteration: 32
# 9174 /10000
# Accuracy is : 91.74
# Epoch Iteration: 33
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 34
# 9177 /10000
# Accuracy is : 91.77
# Epoch Iteration: 35
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 36
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 37
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 38
# 9175 /10000
# Accuracy is : 91.75
# Epoch Iteration: 39
# 9176 /10000
# Accuracy is : 91.76
